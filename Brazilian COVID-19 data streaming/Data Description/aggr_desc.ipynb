# %%
import pandas as pd

# %%
ibge_code = pd.read_csv('/Users/julianeoliveira/Desktop/github/Datasets from the gitcomputations/IBGE_codes/IBGE_geocode_cities.csv',sep=';')

# %%
ibge_code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cod_mun   5570 non-null   int64
#  1   name_mun  5570 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 87.2+ KB

# %%
ibge_code.head()
# Out:
#    cod_mun                 name_mun
# 0  1100015    Alta Floresta D'Oeste
# 1  1100379  Alto Alegre dos Parecis
# 2  1100403             Alto Paraíso
# 3  1100346         Alvorada D'Oeste
# 4  1100023                Ariquemes

# %%
muni_ibp = pd.read_csv('/Users/julianeoliveira/Desktop/Projects/ICODA/Artigo1/Data/mun_ibp.csv')

# %%
muni_ibp.head()
# Out:
#    mun_res  ip_vl_n
# 0   220290   0.7521
# 1   150090   1.6937
# 2   261610   1.0215
# 3   430150  -1.0032
# 4   211176   1.2698

# %%
pop_muni = pd.read_csv('/Users/julianeoliveira/Desktop/github/Datasets from the gitcomputations/Populacao/pop_2021.csv',sep=';')

# %%
pop_muni.head()
# Out:
#        Cod                        Nome     Pop
# 0  1100015  Alta Floresta D'Oeste (RO)   22516
# 1  1100023              Ariquemes (RO)  111148
# 2  1100031                 Cabixi (RO)    5067
# 3  1100049                 Cacoal (RO)   86416
# 4  1100056             Cerejeiras (RO)   16088

# %%
df = pd.read_csv('/Users/julianeoliveira/Desktop/github/Datasets from the gitcomputations/Populacao/pop_ibp.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      Cod                        Nome     Pop    code  UF  \
# 0           0  1100015  Alta Floresta D'Oeste (RO)   22516  110001  RO
# 1           1  1100023              Ariquemes (RO)  111148  110002  RO
# 2           2  1100031                 Cabixi (RO)    5067  110003  RO
# 3           3  1100049                 Cacoal (RO)   86416  110004  RO
# 4           4  1100056             Cerejeiras (RO)   16088  110005  RO
#
#    ip_vl_n
# 0   0.0860
# 1  -0.5361
# 2   0.0332
# 3  -0.7100
# 4  -0.4319

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5570 non-null   int64
#  1   Cod         5570 non-null   int64
#  2   Nome        5570 non-null   object
#  3   Pop         5570 non-null   int64
#  4   code        5570 non-null   int64
#  5   UF          5570 non-null   object
#  6   ip_vl_n     5563 non-null   float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 304.7+ KB

# %%
5570*365*2
# Out:
# 4066100

# %%
df2 = pd.read_excel('/Users/julianeoliveira/Downloads/Base_de_dados_ligacoes_rodoviarias_e_hidroviarias_2016.xlsx')

# %%
df2.head()
# Out:
#                ID  COD_UF_A UF_A  CODMUNDV_A              NOMEMUN_A  COD_UF_B  \
# 0  13026031304260        13   AM     1302603                 Manaus        13
# 1  13021081302603        13   AM     1302108                 Japurá        13
# 2  51038095108402        51   MT     5103809  Figueirópolis D'Oeste        51
# 3  13000291302603        13   AM     1300029               Alvarães        13
# 4  13000291301308        13   AM     1300029               Alvarães        13
#
#   UF_B  CODMUNDV_B      NOMEMUN_B                         VAR01  ... VAR05  \
# 0   AM     1304260         Uarini  Núcleo de Metrópole (Manaus)  ...   7.5
# 1   AM     1302603         Manaus                  Centro Local  ...   3.0
# 2   MT     5108402  Várzea Grande                  Centro Local  ...   0.0
# 3   AM     1302603         Manaus                  Centro Local  ...   7.5
# 4   AM     1301308        Codajás                  Centro Local  ...   6.0
#
# ...

# %%
df2[df2.CODMUNDV_A == 1302603]
# Out:
#                    ID  COD_UF_A UF_A  CODMUNDV_A NOMEMUN_A  COD_UF_B UF_B  \
# 0      13026031304260        13   AM     1302603    Manaus        13   AM
# 15     13026031302801        13   AM     1302603    Manaus        13   AM
# 19     13026031500404        13   AM     1302603    Manaus        15   PA
# 104    13026031504802        13   AM     1302603    Manaus        15   PA
# 110    13026031506005        13   AM     1302603    Manaus        15   PA
# 125    13026031501808        13   AM     1302603    Manaus        15   PA
# 135    13026031500503        13   AM     1302603    Manaus        15   PA
# 167    13026031503101        13   AM     1302603    Manaus        15   PA
# 190    13026031501402        13   AM     1302603    Manaus        15   PA
# 278    13026031505106        13   AM     1302603    Manaus        15   PA
# 309    13026031304104        13   AM     1302603    Manaus        13   AM
# 419    13026031503002        13   AM     1302603    Manaus        15   PA
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65638 entries, 0 to 65637
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          65638 non-null  int64
#  1   COD_UF_A    65638 non-null  int64
#  2   UF_A        65638 non-null  object
#  3   CODMUNDV_A  65638 non-null  int64
#  4   NOMEMUN_A   65638 non-null  object
#  5   COD_UF_B    65638 non-null  int64
#  6   UF_B        65638 non-null  object
#  7   CODMUNDV_B  65638 non-null  int64
#  8   NOMEMUN_B   65638 non-null  object
#  9   VAR01       65636 non-null  object
#  10  VAR02       65495 non-null  object
#  11  VAR03       65638 non-null  float64
#  12  VAR04       65638 non-null  int64
#  13  VAR05       65638 non-null  float64
#  14  VAR06       65638 non-null  float64
#  15  VAR07       65638 non-null  float64
#  16  VAR08       65638 non-null  float64
#  17  VAR09       65638 non-null  float64
#  18  VAR10       65638 non-null  float64
# ...
