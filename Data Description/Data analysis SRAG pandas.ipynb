# %%
import pandas as pd

# %% [markdown]
# # Read data

# %%
df = pd.read_csv('/Volumes/My Passport/PAMEpi_datalake/raw_data_covid19_version-21-12-07/data-sindrome_respiratoria_aguda_grave_incluindo_covid/INFLUD-29-11-2021.csv',sep=';', encoding="utf-8")
# Out:
# /Users/julianeoliveira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (15,18,60,62,63,64,92,94,106,108,115,117,118,119,123,144) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df1 = pd.read_csv('/Volumes/My Passport/PAMEpi_datalake/raw_data_covid19_version-21-12-07/data-sindrome_respiratoria_aguda_grave_incluindo_covid/INFLUD21-29-11-2021.csv',sep=';', encoding="utf-8")

# %%
df.head()
# Out:
#    DT_NOTIFIC  SEM_NOT  DT_SIN_PRI  SEM_PRI SG_UF_NOT          ID_REGIONA  \
# 0  07/01/2020        2  03/01/2020        1        DF                 NaN
# 1  10/01/2020        2  07/01/2020        2        DF                 NaN
# 2  13/02/2020        7  08/02/2020        6        SP   GVE XXXI SOROCABA
# 3  27/01/2020        5  26/01/2020        5        CE    1 CRES FORTALEZA
# 4  16/01/2020        3  10/01/2020        2        SP  GVE XXXIII TAUBATE
#
#    CO_REGIONA ID_MUNICIP  CO_MUN_NOT  \
# 0         NaN   BRASILIA      530010
# 1         NaN   BRASILIA      530010
# 2      1353.0      SALTO      354520
# 3      1519.0  FORTALEZA      230440
# 4      1352.0    TAUBATE      355410
#
#                                           ID_UNIDADE  ...  DS_AN_OUT  \
# 0                HRT HOSPITAL REGIONAL DE TAGUATINGA  ...        NaN
# 1        HOSPITAL MATERNO INFANTIL DR ANTONIO LISBOA  ...        NaN
# 2  HOSPITAL E MATERNIDADE MUNICIPAL N S DO MONTE ...  ...        NaN
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199699 entries, 0 to 1199698
# Columns: 154 entries, DT_NOTIFIC to RES_IGA
# dtypes: float64(87), int64(9), object(58)
# memory usage: 1.4+ GB
